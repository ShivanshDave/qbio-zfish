# %%
import deeplabcut
from glob import glob
from pprint import pprint
# %matplotlib inline

# %%
#path_config_file = '/media/dinesh/home-ext/Experiments/shivansh-fish-dataset/roll-qbio/digitization/Swimming-Shivansh-2018-12-22/config.yaml'
path_config_file = '/home/shivansh/sharing/roll-qbio/digitization/Swimming-Shivansh-2018-12-22/config.yaml'

# %%
deeplabcut.evaluate_network(path_config_file)
# Out:
# Running  DeepCut_resnet50_SwimmingDec22shuffle1_1030000  with # of trainingiterations: 1030000
# INFO:tensorflow:Restoring parameters from /home/shivansh/sharing/roll-qbio/digitization/Swimming-Shivansh-2018-12-22/dlc-models/iteration-0/SwimmingDec22-trainset95shuffle1/train/snapshot-1030000
# INFO:tensorflow:Restoring parameters from /home/shivansh/sharing/roll-qbio/digitization/Swimming-Shivansh-2018-12-22/dlc-models/iteration-0/SwimmingDec22-trainset95shuffle1/train/snapshot-1030000
# 0it [00:00, ?it/s]
# Analyzing data...
# 128it [00:08, 17.24it/s]
# Done and results stored for snapshot:  snapshot-1030000
# Results for 1030000  training iterations: 95 1 train error: 1.46 pixels. Test error: 2.3  pixels.
# With pcutoff of 0.1  train error: 1.46 pixels. Test error: 2.3 pixels
# Thereby, the errors are given by the average distances between the labels by DLC and the scorer.
# The network is evaluated and the results are stored in the subdirectory 'evaluation_results'.
# ...

# %%
videofile_path=glob('*.mp4')[:2]
pprint(videofile_path)
# Out:
# ['e6_f4-CCW-vid_2018-08-17_18-41-41.mp4',
#  'e5_f1-CW-vid_2018-08-17_15-06-18.mp4']

# %%
deeplabcut.analyze_videos(path_config_file, videofile_path)
# Out:
# Using snapshot-1030000 for model /home/shivansh/sharing/roll-qbio/digitization/Swimming-Shivansh-2018-12-22/dlc-models/iteration-0/SwimmingDec22-trainset95shuffle1
# INFO:tensorflow:Restoring parameters from /home/shivansh/sharing/roll-qbio/digitization/Swimming-Shivansh-2018-12-22/dlc-models/iteration-0/SwimmingDec22-trainset95shuffle1/train/snapshot-1030000
# INFO:tensorflow:Restoring parameters from /home/shivansh/sharing/roll-qbio/digitization/Swimming-Shivansh-2018-12-22/dlc-models/iteration-0/SwimmingDec22-trainset95shuffle1/train/snapshot-1030000
#   0%|          | 0/3513 [00:00<?, ?it/s]
# e6_f4-CCW-vid_2018-08-17_18-41-41.mp4
# Starting %  e6_f4-CCW-vid_2018-08-17_18-41-41.mp4
# Loading  e6_f4-CCW-vid_2018-08-17_18-41-41.mp4
# Duration of video [s]:  58.55 , recorded with  60.0 fps!
# Overall # of frames:  3513 without cropped frame dimensions:  1280 1024
# Starting to extract posture
# 3535it [04:39, 12.52it/s]
# Detected frames:  3513
# ...

# %%
deeplabcut.create_labeled_video(path_config_file,videofile_path)
# Out:
#   0%|          | 0/3513 [00:00<?, ?it/s]
#
#   0%|          | 5/3513 [00:00<01:15, 46.55it/s]
# Starting %  . ['e6_f4-CCW-vid_2018-08-17_18-41-41.mp4', 'e5_f1-CW-vid_2018-08-17_15-06-18.mp4']
# Loading  e6_f4-CCW-vid_2018-08-17_18-41-41.mp4 and data.
# False 0 1280 0 1024
# 3513
# Duration of video [s]:  58.55 , recorded with  60.0 fps!
# Overall # of frames:  3513 with cropped frame dimensions:  1280 1024
# Generating frames and creating video.
#   0%|          | 12/3513 [00:00<01:07, 51.73it/s]
#
#   1%|          | 20/3513 [00:00<01:01, 56.68it/s]
#
#   1%|          | 28/3513 [00:00<00:57, 61.01it/s]
#
#   1%|          | 36/3513 [00:00<00:54, 64.12it/s]
#
#   1%|          | 43/3513 [00:00<00:52, 65.69it/s]
#
#   1%|▏         | 51/3513 [00:00<00:51, 67.28it/s]
#
#   2%|▏         | 59/3513 [00:00<00:50, 68.41it/s]
#
#   2%|▏         | 67/3513 [00:00<00:49, 69.41it/s]
#
#   2%|▏         | 75/3513 [00:01<00:49, 69.99it/s]
#
#   2%|▏         | 83/3513 [00:01<00:48, 70.17it/s]
#
# ...
